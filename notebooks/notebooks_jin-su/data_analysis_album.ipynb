# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('../../data/data_with_target.csv')

# %%
df['track_listens']
# Out:
# 0        1293
# 1        1151
# 2       50135
# 3        1299
# 4         725
#         ...
# 7995     2705
# 7996     3589
# 7997      676
# 7998      788
# 7999     1474
# Name: track_listens, Length: 8000, dtype: int64

# %%
x = df.columns.str.contains('album_')
album = df[df.columns[x]]

# %%
x = df[df['track_listens'] < 20000]

# %%
# Plot album_tracks against target variable
sns.scatterplot(data=x, x='album_tracks', y='track_listens')
# Out:
# <Axes: xlabel='album_tracks', ylabel='track_listens'>

# %% [markdown]
# Slight tendency: the more tracks in album, the less listens a track has
