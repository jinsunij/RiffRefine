# %%
# import libraries

import os

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa
import librosa.display

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, cohen_kappa_score, make_scorer
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_predict

RSEED=42

# %%
# read data
df=pd.read_csv('/Users/annelahann/neue-fische/RiffRefine/data/data_with_target.csv')
df.head()
# Out:
#    Unnamed: 0  track_id  album_comments   album_date_created  album_favorites  \
# 0           0         2               0  2008-11-26 01:44:45                4
# 1           1         5               0  2008-11-26 01:44:45                4
# 2           2        10               0  2008-11-26 01:45:08                4
# 3           3       140               1  2008-11-26 01:49:59                1
# 4           4       141               0  2008-11-26 01:49:57                1
#
#    album_id  album_listens            album_title  album_tracks album_type  \
# 0         1           6073   AWOL - A Way Of Life             7      Album
# 1         1           6073   AWOL - A Way Of Life             7      Album
# 2         6          47632      Constant Hitmaker             2      Album
# 3        61           1300         The Blind Spot             1      Album
# 4        60           1304  Every Man For Himself             2      Album
#
#    ...  soundcloud_website track_title_char_count  album_information_bin  \
# 0  ...               False                      4                      1
# 1  ...               False                     10                      1
# 2  ...               False                      7                      0
# 3  ...               False                     18                      1
# 4  ...               False                      4                      1
#
#    artist_bio_bin months_life listens_month bonus_listens listens_incl_bonus  \
# 0               1         101     12.801980           0.0             1293.0
# 1               1         101     11.396040           0.0             1151.0
# 2               1         101    496.386139           0.0            50135.0
# 3               1         101     12.861386           0.0             1299.0
# 4               1         101      7.178218           0.0              725.0
#
#    listens_bins  genre_pred
# 0             2           2
# 1             1           2
# 2             4           1
# 3             2           1
# 4             1           1
#
# [5 rows x 560 columns]

# %%
df['listens_bins']=df['listens_bins']-1
df['listens_bins'].value_counts()
# Out:
# listens_bins
# 1    2054
# 2    2053
# 3    1960
# 0    1933
# Name: count, dtype: int64

# %%
# Define predictors and target variable
mfcc = [col for col in df.columns if col.startswith('mfcc_max')]
chroma = [col for col in df.columns if col.startswith('chroma')]
#chroma1 = [col for col in df.columns if col.startswith('chroma_stft_mean')]
#chroma2 = [col for col in df.columns if col.startswith('chroma_cqt_mean')]
#chroma3 = [col for col in df.columns if col.startswith('chroma_cens_mean')]
rmse = [col for col in df.columns if col.startswith('rmse')]
zcr = [col for col in df.columns if col.startswith('zcr')]
spectral = [col for col in df.columns if col.startswith('spectral')]
#spectral1 = [col for col in df.columns if col.startswith('spectral_rolloff_mean')]
#spectral2 = [col for col in df.columns if col.startswith('spectral_bandwith_mean')]
#spectral3 = [col for col in df.columns if col.startswith('spectral_centroid_mean')]
#spectral4 = [col for col in df.columns if col.startswith('spectral_contrast_mean')]
tonnetz = [col for col in df.columns if col.startswith('tonnetz')]

#X = df[['track_genre_top','track_bit_rate','track_duration','album_information_bin','album_tracks','other_website','soundcloud_website','artist_bio_bin','track_title_char_count']+mfcc+chroma+rmse+zcr+spectral+tonnetz]
#X = df[['track_genre_top','track_bit_rate','track_duration','album_information_bin','artist_website_bin','month']+mfcc+chroma1+chroma2+chroma3+rmse+zcr+spectral1+spectral2+spectral3+spectral4+tonnetz]
X = df[['track_genre_top','track_bit_rate','track_duration','album_information_bin','album_tracks','other_website','soundcloud_website','artist_bio_bin','track_title_char_count']+mfcc]
y = df['listens_bins']
print(f"We have {X.shape[0]} observations in our dataset and {X.shape[1]} features")
print(f"Our target vector has also {y.shape[0]} values")
# Out:
# We have 8000 observations in our dataset and 29 features
# Our target vector has also 8000 values

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   track_genre_top         8000 non-null   object
#  1   track_bit_rate          8000 non-null   int64
#  2   track_duration          8000 non-null   int64
#  3   album_information_bin   8000 non-null   int64
#  4   album_tracks            8000 non-null   int64
#  5   other_website           8000 non-null   bool
#  6   soundcloud_website      8000 non-null   bool
#  7   artist_bio_bin          8000 non-null   int64
#  8   track_title_char_count  8000 non-null   int64
#  9   mfcc_max_01             8000 non-null   float64
#  10  mfcc_max_02             8000 non-null   float64
#  11  mfcc_max_03             8000 non-null   float64
#  12  mfcc_max_04             8000 non-null   float64
#  13  mfcc_max_05             8000 non-null   float64
#  14  mfcc_max_06             8000 non-null   float64
#  15  mfcc_max_07             8000 non-null   float64
#  16  mfcc_max_08             8000 non-null   float64
#  17  mfcc_max_09             8000 non-null   float64
#  18  mfcc_max_10             8000 non-null   float64
#  19  mfcc_max_11             8000 non-null   float64
#  20  mfcc_max_12             8000 non-null   float64
#  21  mfcc_max_13             8000 non-null   float64
#  22  mfcc_max_14             8000 non-null   float64
#  23  mfcc_max_15             8000 non-null   float64
#  24  mfcc_max_16             8000 non-null   float64
#  25  mfcc_max_17             8000 non-null   float64
#  26  mfcc_max_18             8000 non-null   float64
#  27  mfcc_max_19             8000 non-null   float64
#  28  mfcc_max_20             8000 non-null   float64
# dtypes: bool(2), float64(20), int64(6), object(1)
# memory usage: 1.7+ MB

# %%
#OnehotEncoding genre

X = pd.get_dummies(X, columns=['track_genre_top'], drop_first=True)

# %%
# Split into train and test set 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RSEED)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
X_test
# Out:
# X_train shape: (6400, 35)
# X_test shape: (1600, 35)
# y_train shape: (6400,)
# y_test shape: (1600,)
#       track_bit_rate  track_duration  album_information_bin  album_tracks  \
# 2215          320000             209                      1            12
# 2582          256000             275                      1            31
# 1662          256000             255                      1            32
# 3027          320000             265                      1             9
# 4343          228446             494                      1            19
# ...              ...             ...                    ...           ...
# 1079          320000             320                      1            11
# 7979          320000             201                      1             8
# 1115          320000             297                      1             3
# 6093          320000             251                      1             8
# 6832          320000             254                      1            11
#
#       other_website  soundcloud_website  artist_bio_bin  \
# 2215           True               False               0
# 2582          False               False               1
# 1662           True               False               1
# 3027           True               False               1
# 4343          False                True               1
# ...             ...                 ...             ...
# 1079           True               False               0
# 7979           True               False               1
# 1115           True               False               1
# 6093           True               False               1
# 6832           True               False               0
#
#       track_title_char_count  mfcc_max_01  mfcc_max_02  ...  mfcc_max_18  \
# 2215                       9  -127.619438   281.957581  ...     8.348141
# 2582                      11    17.490486   234.586624  ...    32.584328
# 1662                      11    23.280031   275.985931  ...    44.984634
# 3027                      14    59.717487   268.971893  ...    27.418694
# 4343                      27    18.540136   252.293854  ...    36.122959
# ...                      ...          ...          ...  ...          ...
# 1079                      16    50.266823   239.845474  ...    30.628698
# 7979                      19   -33.510094   234.995193  ...    39.744267
# 1115                       7  -178.160660   269.192780  ...    23.439552
# 6093                      44    47.188988   216.207474  ...    29.952868
# 6832                       7    11.131252   244.613220  ...    35.147331
#
#       mfcc_max_19  mfcc_max_20  track_genre_top_Experimental  \
# 2215    10.451492    16.795732                         False
# 2582    32.531086    32.046883                         False
# 1662    39.737503    43.802067                         False
# 3027    24.551201    26.332794                         False
# 4343    28.357897    31.973883                         False
# ...           ...          ...                           ...
# 1079    26.040159    36.166630                         False
# 7979    28.665009    31.513577                         False
# 1115    24.766241    24.095631                          True
# 6093    36.256962    26.283033                         False
# 6832    34.694416    25.789265                         False
#
#       track_genre_top_Folk  track_genre_top_Hip-Hop  \
# 2215                 False                    False
# 2582                 False                    False
# 1662                 False                    False
# 3027                 False                    False
# 4343                 False                    False
# ...                    ...                      ...
# 1079                 False                    False
# 7979                 False                    False
# 1115                 False                    False
# 6093                 False                     True
# 6832                 False                    False
#
#       track_genre_top_Instrumental  track_genre_top_International  \
# 2215                         False                          False
# 2582                         False                          False
# 1662                         False                           True
# 3027                         False                          False
# 4343                         False                          False
# ...                            ...                            ...
# 1079                         False                          False
# 7979                          True                          False
# 1115                         False                          False
# 6093                         False                          False
# 6832                         False                          False
#
#       track_genre_top_Pop  track_genre_top_Rock
# 2215                 True                 False
# 2582                False                  True
# 1662                False                 False
# 3027                False                 False
# 4343                False                 False
# ...                   ...                   ...
# 1079                False                 False
# 7979                False                 False
# 1115                False                 False
# 6093                False                 False
# 6832                 True                 False
#
# [1600 rows x 35 columns]

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 0.80081919, -0.39231651,  0.48309243, ...,  2.67060806,
#         -0.3790436 , -0.37525986],
#        [-1.25900183,  0.06557926, -2.06999723, ..., -0.37444656,
#         -0.3790436 , -0.37525986],
#        [-0.15134508, -1.07407243,  0.48309243, ..., -0.37444656,
#         -0.3790436 , -0.37525986],
#        ...,
#        [ 0.89673488, -0.24986005,  0.48309243, ..., -0.37444656,
#          2.63821891, -0.37525986],
#        [ 0.89673488,  1.81575863,  0.48309243, ..., -0.37444656,
#         -0.3790436 , -0.37525986],
#        [-0.12597827, -0.86038773,  0.48309243, ..., -0.37444656,
#         -0.3790436 , -0.37525986]])

# %%
rf = RandomForestClassifier(n_estimators=100, 
                               random_state=RSEED, 
                               n_jobs=-1, verbose = 1)

rf.fit(X_train_scaled, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.4s finished
# RandomForestClassifier(n_jobs=-1, random_state=42, verbose=1)

# %%
n_nodes = []
max_depths = []

for ind_tree in rf.estimators_:
    n_nodes.append(ind_tree.tree_.node_count)
    max_depths.append(ind_tree.tree_.max_depth)
    
print(f'Average number of nodes {int(np.mean(n_nodes))}')
print(f'Average maximum depth {int(np.mean(max_depths))}')
# Out:
# Average number of nodes 3201
# Average maximum depth 27

# %%
y_train_pred_rf = rf.predict(X_train_scaled)
y_test_pred_rf = rf.predict(X_test_scaled)

y_train_probs_rf = rf.predict_proba(X_train_scaled)[:, 1]
y_test_probs_rf = rf.predict_proba(X_test_scaled)[:, 1]
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
# Performance DT Train Data

conf_matrix= confusion_matrix(y_train, y_train_pred_rf)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
#off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
#print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_train, y_train_pred_rf).round(3))
# Out:
# 100.0
# 0.0
# 0.0
# 0.0
# --------------------------------
# 1.0

# %%
# Performance DT Test Data

conf_matrix= confusion_matrix(y_test, y_test_pred_rf)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
#off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
#print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_test, y_test_pred_rf).round(3))
# Out:
# 54.7
# 34.8
# 8.2
# 2.3
# --------------------------------
# 0.398

# %%
kappa_scorer = make_scorer(cohen_kappa_score)

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'n_estimators': np.linspace(10, 100).astype(int),
    'max_depth': [None] + list(np.linspace(2, 20).astype(int)),
    'max_features': ['auto', 'sqrt', None] + list(np.arange(0.5, 1, 0.1)),
    'max_leaf_nodes': [None] + list(np.linspace(10, 50, 100).astype(int)),
    'min_samples_split': [1,2,3,10],
    'bootstrap': [True, False]
}


# Estimator for use in random search
estimator = RandomForestClassifier(random_state = RSEED)

# Create the random search model
grid_rf = RandomizedSearchCV(estimator, param_grid, n_jobs = -1, 
                        scoring =kappa_scorer, cv = 5, 
                        n_iter = 10, verbose = 5, random_state=RSEED)


grid_rf.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END bootstrap=False, max_depth=16, max_features=0.6, max_leaf_nodes=41, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=16, max_features=0.6, max_leaf_nodes=41, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=16, max_features=0.6, max_leaf_nodes=41, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=16, max_features=0.6, max_leaf_nodes=41, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=17, max_features=0.8999999999999999, max_leaf_nodes=48, min_samples_split=1, n_estimators=44;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=17, max_features=0.8999999999999999, max_leaf_nodes=48, min_samples_split=1, n_estimators=44;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=17, max_features=0.8999999999999999, max_leaf_nodes=48, min_samples_split=1, n_estimators=44;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=17, max_features=0.8999999999999999, max_leaf_nodes=48, min_samples_split=1, n_estimators=44;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=17, max_features=0.8999999999999999, max_leaf_nodes=48, min_samples_split=1, n_estimators=44;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=16, max_features=0.6, max_leaf_nodes=41, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=15, max_features=0.7, max_leaf_nodes=49, min_samples_split=10, n_estimators=79;, score=0.379 total time=   4.8s
# [CV 1/5] END bootstrap=True, max_depth=16, max_features=0.6, max_leaf_nodes=21, min_samples_split=1, n_estimators=72;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=16, max_features=0.6, max_leaf_nodes=21, min_samples_split=1, n_estimators=72;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=16, max_features=0.6, max_leaf_nodes=21, min_samples_split=1, n_estimators=72;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=16, max_features=0.6, max_leaf_nodes=21, min_samples_split=1, n_estimators=72;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=16, max_features=0.6, max_leaf_nodes=21, min_samples_split=1, n_estimators=72;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=19, max_features=0.6, max_leaf_nodes=40, min_samples_split=2, n_estimators=61;, score=0.376 total time=   4.8s
# [CV 1/5] END bootstrap=False, max_depth=19, max_features=0.6, max_leaf_nodes=40, min_samples_split=2, n_estimators=61;, score=0.384 total time=   4.9s
# [CV 4/5] END bootstrap=True, max_depth=15, max_features=0.7, max_leaf_nodes=49, min_samples_split=10, n_estimators=79;, score=0.370 total time=   5.0s
# [CV 4/5] END bootstrap=False, max_depth=19, max_features=0.6, max_leaf_nodes=40, min_samples_split=2, n_estimators=61;, score=0.387 total time=   5.0s
# [CV 2/5] END bootstrap=True, max_depth=15, max_features=0.7, max_leaf_nodes=49, min_samples_split=10, n_estimators=79;, score=0.399 total time=   5.1s
# [CV 5/5] END bootstrap=True, max_depth=15, max_features=0.7, max_leaf_nodes=49, min_samples_split=10, n_estimators=79;, score=0.359 total time=   5.2s
# [CV 3/5] END bootstrap=True, max_depth=15, max_features=0.7, max_leaf_nodes=49, min_samples_split=10, n_estimators=79;, score=0.357 total time=   5.3s
# [CV 1/5] END bootstrap=False, max_depth=5, max_features=0.5, max_leaf_nodes=12, min_samples_split=10, n_estimators=11;, score=0.344 total time=   0.5s
# [CV 4/5] END bootstrap=False, max_depth=5, max_features=0.5, max_leaf_nodes=12, min_samples_split=10, n_estimators=11;, score=0.357 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=5, max_features=0.5, max_leaf_nodes=12, min_samples_split=10, n_estimators=11;, score=0.357 total time=   0.5s
# [CV 5/5] END bootstrap=False, max_depth=5, max_features=0.5, max_leaf_nodes=12, min_samples_split=10, n_estimators=11;, score=0.344 total time=   0.6s
# [CV 3/5] END bootstrap=False, max_depth=5, max_features=0.5, max_leaf_nodes=12, min_samples_split=10, n_estimators=11;, score=0.332 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=11, max_features=0.7, max_leaf_nodes=13, min_samples_split=10, n_estimators=50;, score=0.363 total time=   2.6s
# [CV 5/5] END bootstrap=True, max_depth=11, max_features=0.7, max_leaf_nodes=13, min_samples_split=10, n_estimators=50;, score=0.341 total time=   2.5s
# [CV 3/5] END bootstrap=True, max_depth=11, max_features=0.7, max_leaf_nodes=13, min_samples_split=10, n_estimators=50;, score=0.341 total time=   2.6s
# [CV 3/5] END bootstrap=False, max_depth=19, max_features=0.6, max_leaf_nodes=40, min_samples_split=2, n_estimators=61;, score=0.348 total time=   5.0s
# [CV 5/5] END bootstrap=False, max_depth=19, max_features=0.6, max_leaf_nodes=40, min_samples_split=2, n_estimators=61;, score=0.358 total time=   5.1s
# [CV 2/5] END bootstrap=True, max_depth=11, max_features=0.7, max_leaf_nodes=13, min_samples_split=10, n_estimators=50;, score=0.381 total time=   2.6s
# [CV 2/5] END bootstrap=False, max_depth=13, max_features=0.5, max_leaf_nodes=16, min_samples_split=2, n_estimators=87;, score=0.382 total time=   4.9s
# [CV 4/5] END bootstrap=True, max_depth=11, max_features=0.7, max_leaf_nodes=13, min_samples_split=10, n_estimators=50;, score=0.362 total time=   2.5s
# [CV 1/5] END bootstrap=False, max_depth=18, max_features=0.7, max_leaf_nodes=24, min_samples_split=3, n_estimators=57;, score=0.366 total time=   4.5s
# [CV 4/5] END bootstrap=False, max_depth=13, max_features=0.5, max_leaf_nodes=16, min_samples_split=2, n_estimators=87;, score=0.354 total time=   4.8s
# [CV 1/5] END bootstrap=False, max_depth=13, max_features=0.5, max_leaf_nodes=16, min_samples_split=2, n_estimators=87;, score=0.362 total time=   4.8s
# [CV 3/5] END bootstrap=False, max_depth=18, max_features=0.7, max_leaf_nodes=24, min_samples_split=3, n_estimators=57;, score=0.337 total time=   4.7s
# [CV 5/5] END bootstrap=False, max_depth=18, max_features=0.7, max_leaf_nodes=24, min_samples_split=3, n_estimators=57;, score=0.339 total time=   4.6s
# [CV 4/5] END bootstrap=True, max_depth=6, max_features=0.7999999999999999, max_leaf_nodes=34, min_samples_split=2, n_estimators=81;, score=0.355 total time=   4.5s
# [CV 2/5] END bootstrap=True, max_depth=6, max_features=0.7999999999999999, max_leaf_nodes=34, min_samples_split=2, n_estimators=81;, score=0.376 total time=   4.6s
# [CV 2/5] END bootstrap=False, max_depth=18, max_features=0.7, max_leaf_nodes=24, min_samples_split=3, n_estimators=57;, score=0.384 total time=   4.7s
# [CV 3/5] END bootstrap=False, max_depth=13, max_features=0.5, max_leaf_nodes=16, min_samples_split=2, n_estimators=87;, score=0.347 total time=   5.0s
# [CV 5/5] END bootstrap=False, max_depth=13, max_features=0.5, max_leaf_nodes=16, min_samples_split=2, n_estimators=87;, score=0.344 total time=   4.7s
# [CV 5/5] END bootstrap=True, max_depth=6, max_features=0.7999999999999999, max_leaf_nodes=34, min_samples_split=2, n_estimators=81;, score=0.341 total time=   3.8s
# [CV 1/5] END bootstrap=True, max_depth=6, max_features=0.7999999999999999, max_leaf_nodes=34, min_samples_split=2, n_estimators=81;, score=0.355 total time=   3.0s
# [CV 3/5] END bootstrap=True, max_depth=6, max_features=0.7999999999999999, max_leaf_nodes=34, min_samples_split=2, n_estimators=81;, score=0.346 total time=   3.0s
# [CV 4/5] END bootstrap=False, max_depth=18, max_features=0.7, max_leaf_nodes=24, min_samples_split=3, n_estimators=57;, score=0.367 total time=   3.3s
# /Users/annelahann/neue-fische/RiffRefine/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 15 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/annelahann/neue-fische/RiffRefine/.venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/annelahann/neue-fische/RiffRefine/.venv/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/annelahann/neue-fische/RiffRefine/.venv/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/annelahann/neue-fische/RiffRefine/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/annelahann/neue-fische/RiffRefine/.venv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.37279378 0.37074476        nan 0.34679326
#  0.35783293 0.35780745 0.35853404 0.3544394 ]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 2, 2, 2, 3, 3, 3, 4,
#                                                       4, 4, 5, 5, 6, 6, 6, 7, 7,
#                                                       7, 8, 8, 8, 9, 9, 10, 10,
#                                                       10, 11, 11, 11, 12, ...],
#                                         'max_features': ['auto', 'sqrt', None,
#                                                          0.5, 0.6, 0.7,
#                                                          0.7999999999999999,
#                                                          0.8999999999999999],
#                                         'max_leaf_nodes': [None, 10, 10, 10, 11,
#                                                            11, 12, 12, 12, 13,
#                                                            13, 14, 14, 14, 15,
#                                                            15, 16, 16, 16, 17,
#                                                            17, 18, 18, 18, 19,
#                                                            19, 20, 20, 20, 21, ...],
#                                         'min_samples_split': [1, 2, 3, 10],
#                                         'n_estimators': array([ 10,  11,  13,  15,  17,  19,  21,  22,  24,  26,  28,  30,  32,
#         33,  35,  37,  39,  41,  43,  44,  46,  48,  50,  52,  54,  55,
#         57,  59,  61,  63,  65,  66,  68,  70,  72,  74,  76,  77,  79,
#         81,  83,  85,  87,  88,  90,  92,  94,  96,  98, 100])},
#                    random_state=42, scoring=make_scorer(cohen_kappa_score),
#                    verbose=5)

# %%
# Show best parameters
grid_rf.best_params_
# Out:
# {'n_estimators': 79,
#  'min_samples_split': 10,
#  'max_leaf_nodes': 49,
#  'max_features': 0.7,
#  'max_depth': 15,
#  'bootstrap': True}

# %%
# Save best model (including fitted preprocessing steps) as best_model 

best_model = grid_rf.best_estimator_
best_model.feature_importances_
# Out:
# array([0.02027225, 0.0113985 , 0.00214747, 0.04602261, 0.0023408 ,
#        0.00087359, 0.00109476, 0.00545109, 0.0469058 , 0.01767964,
#        0.01420709, 0.01298613, 0.02054538, 0.00923779, 0.01891689,
#        0.01139126, 0.01100729, 0.01411424, 0.01216164, 0.00796304,
#        0.00825778, 0.01061958, 0.00794445, 0.00866534, 0.00475477,
#        0.00663867, 0.0055507 , 0.00555136, 0.10419598, 0.07968093,
#        0.09715418, 0.07547757, 0.1150555 , 0.09081385, 0.09292211])

# %%
y_train_pred_rf = best_model.predict(X_train_scaled)
y_test_pred_rf = best_model.predict(X_test_scaled)

y_train_probs_rf = best_model.predict_proba(X_train_scaled)[:, 1]
y_test_probs_rf = best_model.predict_proba(X_test_scaled)[:, 1]

# %%
conf_matrix= confusion_matrix(y_test, y_test_pred_rf)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
#off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
#print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_test, y_test_pred_rf).round(3))
# Out:
# 54.3
# 33.2
# 9.4
# 3.0
# --------------------------------
# 0.394

# %%
conf_matrix= confusion_matrix(y_train, y_train_pred_rf)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
#off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
#print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_train, y_train_pred_rf).round(3))
# Out:
# 58.6
# 29.6
# 8.9
# 2.9
# --------------------------------
# 0.449

# %%
from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(best_model, X_train_scaled, y_train,random_state=RSEED)

sorted_idx = perm_importance.importances_mean.argsort()[::-1]
feature_names = X.columns.tolist() 
top_features = 25  
plt.figure(figsize=(10, 6))
plt.bar(range(top_features), perm_importance.importances_mean[sorted_idx][:top_features], align="center")
plt.xticks(range(top_features), [feature_names[i] for i in sorted_idx[:top_features]], rotation=90)
plt.xlabel('Features')
plt.ylabel('Permutation Importance')
plt.title('Permutation Feature Importance of Top-Features')
plt.show()

# %%
from xgboost import XGBClassifier, plot_importance

xgb = XGBClassifier(random_state=RSEED, tree_method="hist",max_depth=5,gamma=1.0,learning_rate=0.1,reg_lambda=2,scale_pos_weight=1,n_estimators=75)
xgb.fit(X_train_scaled, y_train)
# Out:
# /Users/annelahann/neue-fische/RiffRefine/.venv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [12:13:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=1.0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=75, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_train_pred_xgb = xgb.predict(X_train_scaled)
y_test_pred_xgb = xgb.predict(X_test_scaled)

# %%
conf_matrix= confusion_matrix(y_train, y_train_pred_xgb)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
#off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
#print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_train, y_train_pred_xgb).round(3))
# Out:
# 68.3
# 22.5
# 7.2
# 1.9
# --------------------------------
# 0.578

# %%
conf_matrix= confusion_matrix(y_test, y_test_pred_xgb)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
#off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
#print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_test, y_test_pred_xgb).round(3))
# Out:
# 54.4
# 34.1
# 9.1
# 2.5
# --------------------------------
# 0.394

# %%
grid_params = {
    'n_estimators': [70,100],
    'gamma': [0.5,1.0],
   # 'reg_lambda': [1.0,2.0,5.0],
    'max_depth': [3,5,8],
    'learning_rate': [0.01,0.1,0.5]
}

gs = GridSearchCV(
    XGBClassifier(random_state=RSEED, tree_method="hist"),
    grid_params,
    verbose=1,
    cv=3,
    n_jobs=-1,
    scoring=kappa_scorer)

# %%
xgb_gs = gs.fit(X_train_scaled, y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits

# %%
xgb_gs.best_params_
# Out:
# {'gamma': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}

# %%
best_model = xgb_gs.best_estimator_

# %%
from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(best_model, X_train_scaled, y_train,random_state=RSEED)

sorted_idx = perm_importance.importances_mean.argsort()[::-1]
feature_names = X.columns.tolist() 
top_features = 25  
plt.figure(figsize=(10, 6))
plt.bar(range(top_features), perm_importance.importances_mean[sorted_idx][:top_features], align="center")
plt.xticks(range(top_features), [feature_names[i] for i in sorted_idx[:top_features]], rotation=90)
plt.xlabel('Features')
plt.ylabel('Permutation Importance')
plt.title('Permutation Feature Importance of Top-Features')
plt.show()

# %%
y_train_pred_xgb = best_model.predict(X_train_scaled)
y_test_pred_xgb = best_model.predict(X_test_scaled)

# %%
conf_matrix= confusion_matrix(y_train, y_train_pred_xgb)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_train, y_train_pred_xgb).round(3))
# Out:
# 72.9
# 20.0
# 5.7
# 1.5
# 0.0
# --------------------------------
# 0.638

# %%
conf_matrix= confusion_matrix(y_test, y_test_pred_xgb)
accurate_classes = sum([conf_matrix[i][i] for i in range(len(conf_matrix))])
off_by_one = sum([conf_matrix[i][j] if abs(i - j) == 1 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_two = sum([conf_matrix[i][j] if abs(i - j) == 2 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_three = sum([conf_matrix[i][j] if abs(i - j) == 3 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])
off_by_four = sum([conf_matrix[i][j] if abs(i - j) == 4 else 0 for i in range(len(conf_matrix)) for j in range(len(conf_matrix))])

print((100*accurate_classes/conf_matrix.sum()).round(1))
print((100*off_by_one/conf_matrix.sum()).round(1))
print((100*off_by_two/conf_matrix.sum()).round(1))
print((100*off_by_three/conf_matrix.sum()).round(1))
print((100*off_by_four/conf_matrix.sum()).round(1))
print('--------------------------------')
print(cohen_kappa_score(y_test, y_test_pred_xgb).round(3))
# Out:
# 54.6
# 34.9
# 8.3
# 2.2
# 0.0
# --------------------------------
# 0.396
